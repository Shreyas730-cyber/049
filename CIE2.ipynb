# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyas730-cyber/049/blob/main/CIE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/tips.csv', usecols=['total_bill','tip'])
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
# dtypes: float64(2)
# memory usage: 3.9 KB
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df.isnull()
# Out:
#      total_bill    tip
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ..          ...    ...
# 239       False  False
# 240       False  False
# 241       False  False
# 242       False  False
# 243       False  False
#
# [244 rows x 2 columns]

# %%
new_df=df.fillna(0)
new_df
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.scatter(df['total_bill'],df['tip'],color='pink')
plt.title('Scatter plot of total_bill vs tip')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()
